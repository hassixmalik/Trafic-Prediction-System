# %%
import cv2

# Define the RGB value of the color to detect (red)
BGR_RED =(50, 60, 240)

# Load all the images and store them in a dictionary
IMAGES = {}
for i in range(8, 18):
    for j in range(0, 60, 30):
        hour = f"{i:02}_{j:02}"
        if i < 12:
            filename = f"{hour}am.png"
        elif i == 12:
            filename = f"{hour}pm.png"
        else:
            filename = f"{i-12:02}_{j:02}pm.png"
        image = cv2.imread(filename)
        IMAGES[hour] = image

# Define a function to perform blob detection on an image
def detect_blobs(image):
    # Convert the image to grayscale
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    # Apply a Gaussian blur to reduce noise
    blurred = cv2.GaussianBlur(gray, (11, 11), 0)
    # Perform blob detection using the SimpleBlobDetector in OpenCV
    detector = cv2.SimpleBlobDetector_create()
    keypoints = detector.detect(blurred)
    # Draw circles around the detected blobs
    output = cv2.drawKeypoints(image, keypoints, None, BGR_RED, cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)
    # Return the output image and the number of detected blobs
    return output, len(keypoints)

# Ask the user for input
user_input = input("Enter hour between 8am and 5pm (e.g. 8am, 8_30am, 9am, etc.): ")

# Check if the input is valid
if user_input not in IMAGES:
    print("Invalid input")
else:
    # Get the corresponding image and perform blob detection
    image = IMAGES[user_input]
    output_image, num_blobs = detect_blobs(image)
    # Show the output image and the number of detected blobs
    cv2.imshow("Output", output_image)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
    if num_blobs > 0:
        print(f"{num_blobs} blobs detected in {user_input}.")
    else:
        print(f"No blobs detected in {user_input}.")
# Out:
# Enter hour between 8am and 5pm (e.g. 8am, 8_30am, 9am, etc.): 14_00
# 66 blobs detected in 14_00.

# %%
#working code hahahahahahahahahahahahahha
import cv2
import numpy as np

# Define the HSV range for red color
lower_red = np.array([0, 50, 50])
upper_red = np.array([10, 255, 255])
lower_red2 = np.array([170, 50, 50])
upper_red2 = np.array([180, 255, 255])


# Load the image
img = cv2.imread('04_30pm.png')

# Convert the image to HSV color space
hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)

# Threshold the image to get the red lines
mask1 = cv2.inRange(hsv, lower_red, upper_red)
mask2 = cv2.inRange(hsv, lower_red2, upper_red2)
mask = cv2.bitwise_or(mask1, mask2)

# Apply some morphological operations to clean up the mask
kernel = np.ones((5, 5), np.uint8)
mask = cv2.morphologyEx(mask, cv2.MORPH_OPEN, kernel)
mask = cv2.morphologyEx(mask, cv2.MORPH_CLOSE, kernel)

# Find contours in the mask
contours, hierarchy = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# Draw the contours on the original image
cv2.drawContours(img, contours, -1, (0, 0, 255), 2)

# Display the image and the number of red lines detected
cv2.imshow('image', img)
cv2.waitKey(0)
cv2.destroyAllWindows()

print(f"Number of red lines detected: {len(contours)}")
# Out:
# Number of red lines detected: 4

# %%
import cv2
import numpy as np

# Define the RGB value of the color to detect (red)
BGR_RED = (50, 60, 240)

# Load all the images and store them in a dictionary
IMAGES = {}
for i in range(8, 18):
    for j in range(0, 60, 30):
        hour = f"{i:02}_{j:02}"
        if i < 12:
            filename = f"{hour}am.png"
        elif i == 12:
            filename = f"{hour}pm.png"
        else:
            filename = f"{i-12:02}_{j:02}pm.png"
        image = cv2.imread(filename)
        IMAGES[hour] = image

# Define the HSV range for red color
lower_red = np.array([0, 50, 50])
upper_red = np.array([10, 255, 255])
lower_red2 = np.array([170, 50, 50])
upper_red2 = np.array([180, 255, 255])

# Define a function to perform blob detection on an image
def detect_blobs(image):
    # Convert the image to HSV color space
    hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
    # Threshold the image to get the red blobs
    mask1 = cv2.inRange(hsv, lower_red, upper_red)
    mask2 = cv2.inRange(hsv, lower_red2, upper_red2)
    mask = cv2.bitwise_or(mask1, mask2)
    # Apply some morphological operations to clean up the mask
    kernel = np.ones((5, 5), np.uint8)
    mask = cv2.morphologyEx(mask, cv2.MORPH_OPEN, kernel)
    mask = cv2.morphologyEx(mask, cv2.MORPH_CLOSE, kernel)
    # Perform blob detection using the SimpleBlobDetector in OpenCV
    detector = cv2.SimpleBlobDetector_create()
    keypoints = detector.detect(mask)
    # Draw circles around the detected blobs
    output = cv2.drawKeypoints(image, keypoints, None, BGR_RED, cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)
    # Return the output image and the number of detected blobs
    return output, len(keypoints)

# Ask the user for input
user_input = input("Enter hour between 8am and 5pm (e.g. 8am, 8_30am, 9am, etc.): ")

# Check if the input is valid
if user_input not in IMAGES:
    print("Invalid input")
else:
    # Get the corresponding image and perform blob detection
    image = IMAGES[user_input]
    output_image, num_blobs = detect_blobs(image)
    # Show the output image and the number of detected blobs
    cv2.imshow("Output", output_image)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
    if num_blobs > 0:
        print(f"{num_blobs} blobs detected in {user_input}.")
    else:
        print(f"No blobs detected in {user_input}.")
# Out:
# Enter hour between 8am and 5pm (e.g. 8am, 8_30am, 9am, etc.): 08_00
# No blobs detected in 08_00.
